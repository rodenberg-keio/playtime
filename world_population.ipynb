# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (2.1.4)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy<2,>=1.22.4 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from pandas) (1.24.4)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install kagglehub
# Out:
# Collecting kagglehub
#   Downloading kagglehub-1.0.0-py3-none-any.whl (70 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.6/70.6 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from kagglehub) (4.64.1)
# Requirement already satisfied: packaging in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from kagglehub) (23.0)
# Collecting kagglesdk<1.0,>=0.1.14
#   Downloading kagglesdk-0.1.15-py3-none-any.whl (160 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.4/160.4 kB 10.4 MB/s eta 0:00:00
# Requirement already satisfied: requests in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from kagglehub) (2.28.2)
# Requirement already satisfied: pyyaml in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from kagglehub) (6.0)
# Requirement already satisfied: protobuf in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from kagglesdk<1.0,>=0.1.14->kagglehub) (4.25.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from requests->kagglehub) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from requests->kagglehub) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from requests->kagglehub) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from requests->kagglehub) (1.26.14)
# Installing collected packages: kagglesdk, kagglehub
# Successfully installed kagglehub-1.0.0 kagglesdk-0.1.15
# Note: you may need to restart the kernel to use updated packages.

# %%
# Install dependencies as needed:
# pip install kagglehub[pandas-datasets]
import kagglehub
from kagglehub import KaggleDatasetAdapter

# Set the path to the file you'd like to load
file_path = "world_population.csv"

# Load the latest version
df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "iamsouravbanerjee/world-population-dataset",
  file_path,
  # Provide any additional arguments like 
  # sql_query or pandas_kwargs. See the 
  # documenation for more information:
  # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
)
# Out:
# /var/folders/qg/wrwcyc613t9dps97nk_gtmhc0000gn/T/ipykernel_36727/406693976.py:10: DeprecationWarning: Use dataset_load() instead of load_dataset(). load_dataset() will be removed in a future version.
#   df = kagglehub.load_dataset(
# First 5 records:    Rank CCA3 Country/Territory           Capital Continent  2022 Population  \
# 0    36  AFG       Afghanistan             Kabul      Asia         41128771
# 1   138  ALB           Albania            Tirana    Europe          2842321
# 2    34  DZA           Algeria           Algiers    Africa         44903225
# 3   213  ASM    American Samoa         Pago Pago   Oceania            44273
# 4   203  AND           Andorra  Andorra la Vella    Europe            79824
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0         38972230         33753499         28189672         19542982
# 1          2866849          2882481          2913399          3182021
# 2         43451666         39543154         35856344         30774621
# 3            46189            51368            54849            58230
# 4            77700            71746            71519            66097
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# 0         10694796         12486631         10752971      652230
# 1          3295066          2941651          2324731       28748
# 2         25518074         18739378         13795915     2381741
# 3            47818            32886            27075         199
# 4            53569            35611            19860         468
#
#    Density (per km²)  Growth Rate  World Population Percentage
# 0            63.0587       1.0257                         0.52
# 1            98.8702       0.9957                         0.04
# 2            18.8531       1.0164                         0.56
# 3           222.4774       0.9831                         0.00
# 4           170.5641       1.0100                         0.00

# %%
df2 = df.head(10)
# Out:
#    Rank CCA3    Country/Territory           Capital      Continent  \
# 0    36  AFG          Afghanistan             Kabul           Asia
# 1   138  ALB              Albania            Tirana         Europe
# 2    34  DZA              Algeria           Algiers         Africa
# 3   213  ASM       American Samoa         Pago Pago        Oceania
# 4   203  AND              Andorra  Andorra la Vella         Europe
# 5    42  AGO               Angola            Luanda         Africa
# 6   224  AIA             Anguilla        The Valley  North America
# 7   201  ATG  Antigua and Barbuda      Saint John’s  North America
# 8    33  ARG            Argentina      Buenos Aires  South America
# 9   140  ARM              Armenia           Yerevan           Asia
#
#    2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771         38972230         33753499         28189672
# 1          2842321          2866849          2882481          2913399
# 2         44903225         43451666         39543154         35856344
# 3            44273            46189            51368            54849
# 4            79824            77700            71746            71519
# 5         35588987         33428485         28127721         23364185
# 6            15857            15585            14525            13172
# 7            93763            92664            89941            85695
# 8         45510318         45036032         43257065         41100123
# 9          2780469          2805608          2878595          2946293
#
#    2000 Population  1990 Population  1980 Population  1970 Population  \
# 0         19542982         10694796         12486631         10752971
# 1          3182021          3295066          2941651          2324731
# 2         30774621         25518074         18739378         13795915
# 3            58230            47818            32886            27075
# 4            66097            53569            35611            19860
# 5         16394062         11828638          8330047          6029700
# 6            11047             8316             6560             6283
# 7            75055            63328            64888            64516
# 8         37070774         32637657         28024803         23842803
# 9          3168523          3556539          3135123          2534377
#
#    Area (km²)  Density (per km²)  Growth Rate  World Population Percentage
# 0      652230            63.0587       1.0257                         0.52
# 1       28748            98.8702       0.9957                         0.04
# 2     2381741            18.8531       1.0164                         0.56
# 3         199           222.4774       0.9831                         0.00
# 4         468           170.5641       1.0100                         0.00
# 5     1246700            28.5466       1.0315                         0.45
# 6          91           174.2527       1.0066                         0.00
# 7         442           212.1335       1.0058                         0.00
# 8     2780400            16.3683       1.0052                         0.57
# 9       29743            93.4831       0.9962                         0.03
